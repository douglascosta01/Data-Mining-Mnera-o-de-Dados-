# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
employee_df = pd.read_csv('/content/human_resources.csv')

# %%
employee_df.shape
# Out:
# (1470, 35)

# %%
employee_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2da85bbc9e64> in <module>()
# ----> 1 employee_df.head()
#
# NameError: name 'employee_df' is not defined

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
employee_df.describe()
# Out:
#                Age    DailyRate  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000  ...              1470.000000           1470.000000
# mean     36.923810   802.485714  ...                 2.187755              4.123129
# std       9.135373   403.509100  ...                 3.222430              3.568136
# min      18.000000   102.000000  ...                 0.000000              0.000000
# 25%      30.000000   465.000000  ...                 0.000000              2.000000
# 50%      36.000000   802.000000  ...                 1.000000              3.000000
# 75%      43.000000  1157.000000  ...                 3.000000              7.000000
# max      60.000000  1499.000000  ...                15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
employee_df['Attrition'] = employee_df['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
employee_df.head()

# %%
employee_df['OverTime'] = employee_df['OverTime'].apply(lambda x: 1 if x ==   'Yes' else 0) 
employee_df['Over18'] = employee_df['Over18'].apply(lambda x: 1 if x ==   'Y' else 0)

# %%
employee_df.head()
# Out:
#    Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1  ...                       0                     5
# 1   49          0  ...                       1                     7
# 2   37          1  ...                       0                     0
# 3   33          0  ...                       3                     0
# 4   27          0  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
sns.heatmap(employee_df.isnull());

# %%
employee_df.hist(bins = 30, figsize=(20, 20), color = 'r');

# %%
 employee_df.drop(['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis= 1, inplace=True)

# %%
employee_df.head()
# Out:
#    Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1  ...                       0                     5
# 1   49          0  ...                       1                     7
# 2   37          1  ...                       0                     0
# 3   33          0  ...                       3                     0
# 4   27          0  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
left_df = employee_df[employee_df['Attrition'] == 1]
stayed_df = employee_df[employee_df['Attrition'] == 0]

# %%
print('Total de empregados= ', len(employee_df))
print('Número de funcionários que sairam da empresa= ', len(left_df))
print('Porcentagem de funcionários que sairam da empresa= ', (len(left_df) / len(employee_df)) * 100)
print('Número de funcionários que ficaram da empresa= ', len(stayed_df))
print('Porcentagem de funcionários que ficaram da empresa= ', (len(stayed_df) / len(employee_df)) * 100)
# Out:
# Total de empregados=  1470
# Número de funcionários que sairam da empresa=  237
# Porcentagem de funcionários que sairam da empresa=  16.122448979591837
# Número de funcionários que ficaram da empresa=  1233
# Porcentagem de funcionários que ficaram da empresa=  83.87755102040816

# %%
left_df.describe()
# Out:
#               Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  237.000000      237.0  ...               237.000000            237.000000
# mean    33.607595        1.0  ...                 1.945148              2.852321
# std      9.689350        0.0  ...                 3.153077              3.143349
# min     18.000000        1.0  ...                 0.000000              0.000000
# 25%     28.000000        1.0  ...                 0.000000              0.000000
# 50%     32.000000        1.0  ...                 1.000000              2.000000
# 75%     39.000000        1.0  ...                 2.000000              5.000000
# max     58.000000        1.0  ...                15.000000             14.000000
#
# [8 rows x 27 columns]

# %%
stayed_df.describe()
# Out:
#                Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1233.000000     1233.0  ...              1233.000000           1233.000000
# mean     37.561233        0.0  ...                 2.234388              4.367397
# std       8.888360        0.0  ...                 3.234762              3.594116
# min      18.000000        0.0  ...                 0.000000              0.000000
# 25%      31.000000        0.0  ...                 0.000000              2.000000
# 50%      36.000000        0.0  ...                 1.000000              3.000000
# 75%      43.000000        0.0  ...                 3.000000              7.000000
# max      60.000000        0.0  ...                15.000000             17.000000
#
# [8 rows x 27 columns]

# %%
correlations = employee_df.corr()
f, ax =plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, annot=True);

# %%
plt.figure(figsize=[25,12])
sns.countplot(x = 'Age', hue = 'Attrition', data=employee_df);

# %%
plt.figure(figsize=[20, 20])
plt.subplot(411)
sns.countplot(x = 'JobRole', hue = 'Attrition', data = employee_df)
plt.figure(figsize=[20, 20])
plt.subplot(412)
sns.countplot(x = 'MaritalStatus', hue = 'Attrition', data = employee_df)
plt.figure(figsize=[20, 20])
plt.subplot(413)
sns.countplot(x = 'JobInvolvement', hue = 'Attrition', data = employee_df)
plt.figure(figsize=[20, 20])
plt.subplot(414)
sns.countplot(x = 'JobLevel', hue = 'Attrition', data = employee_df)
